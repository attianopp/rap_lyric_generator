# %% [markdown]
# # Baseline LSTM model
#
# Code inspired by [this blog post](https://www.analyticsvidhya.com/blog/2020/08/build-a-natural-language-generation-nlg-system-using-pytorch/)

# %% [markdown]
# ### Dataset Class

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset
import re

class RapDataset(Dataset):

  def __init__(self, file_name):
    file_pd = pd.read_csv(file_name)
    # Artist not considered
    # Returns numpy array, shape: (num_lines, 1)
    x = file_pd.iloc[1:1000, 1:].values.flatten().tolist()

    # Clean text
    x = [re.sub("[^-a-z0-9' ]", "", i) for i in x]

    # Create ngrams
    ngrams = [self.create_ngram(i) for i in x]

    # merge list-of-lists into a single list
    ngrams = sum(ngrams, [])

    # create inputs and targets
    inputs = []
    targets = []

    for s in ngrams:
      inputs.append(" ".join(s.split()[:-1]))
      targets.append(" ".join(s.split()[1:]))
 
    # create integer-to-token mapping
    self.int2token = {}
    cnt = 0

    for w in set(" ".join(x).split()):
      self.int2token[cnt] = w
      cnt+= 1

    # create token-to-integer mapping
    self.token2int = {t: i for i, t in self.int2token.items()}

    # convert text sequences to integer sequences
    self.inputs_int = [self.get_integer_seq(i) for i in inputs]
    self.targets_int = [self.get_integer_seq(i) for i in targets]

    self.inputs_int = torch.tensor(self.inputs_int, dtype=torch.long)
    self.targets_int = torch.tensor(self.targets_int, dtype=torch.long)

    # set vocabulary size
    self.vocab_size = len(self.int2token)

  def create_ngram(self, text, n=5):
    ngrams = []

    if len(text.split()) > n:
      for i in range(n, len(text.split())):
        # select ngram of tokens
        seq = text.split()[i-n:i+1]
        # add to the list
        ngrams.append(" ".join(seq))

      return ngrams
    else:
      return [text]

  def get_integer_seq(self, seq):
    return [self.token2int[w] for w in seq.split()]

  def __len__(self):
    return len(self.inputs_int)

  def __getitem__(self, idx):
    return self.inputs_int[idx], self.targets_int[idx]

# %%
# Create Dataset
D = RapDataset('/data-disk/rap/cleaned_lyrics.csv')

# %% [markdown]
# ### LSTM Model Class

# %%
import torch.nn as nn
import torch.nn.functional as F

class WordLSTM(nn.Module):
    
    def __init__(self, vocab_size, n_hidden=256, n_layers=4, drop_prob=0.3, lr=0.001):
        super().__init__()

        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        
        self.emb_layer = nn.Embedding(vocab_size, 200)

        ## define the LSTM
        self.lstm = nn.LSTM(200, n_hidden, n_layers, 
                            dropout=drop_prob, batch_first=True)
        
        ## define a dropout layer
        self.dropout = nn.Dropout(drop_prob)
        
        ## define the fully-connected layer
        self.fc = nn.Linear(n_hidden, vocab_size)      
    
    def forward(self, x, hidden):
        ''' Forward pass through the network. 
            These inputs are x, and the hidden/cell state `hidden`. '''

        ## pass input through embedding layer
        embedded = self.emb_layer(x)     
        
        ## Get the outputs and the new hidden state from the lstm
        lstm_output, hidden = self.lstm(embedded, hidden)
        
        ## pass through a dropout layer
        out = self.dropout(lstm_output)
        
        ## stack output embeddings 
        out = out.reshape(-1, self.n_hidden) 

        ## put "out" through the fully-connected layer
        out = self.fc(out)

        # return the final output and the hidden state
        return out, hidden
    
    
    def init_hidden(self, batch_size):
        ''' initializes hidden state '''
        # Create two new tensors with sizes n_layers x batch_size x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data

        # if GPU is available
        if (torch.cuda.is_available()):
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
        
        # if GPU is not available
        else:
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
        
        return hidden

# %%
# instantiate the model
net = WordLSTM(vocab_size=D.vocab_size)

net.cuda()

print(net)
# Out:
# WordLSTM(
#   (emb_layer): Embedding(21291, 200)
#   (lstm): LSTM(200, 256, num_layers=4, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=21291, bias=True)
# )

# %% [markdown]
# ### Model Training

# %%
def train(net, data_set, epochs=10, batch_size=32, lr=0.001, clip=1, print_every=32):
    
    # optimizer
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    
    # loss
    criterion = nn.CrossEntropyLoss()

    # Data Loader
    train_loader = torch.utils.data.DataLoader(data_set, batch_size=batch_size, shuffle=True, drop_last=True)
    
    # push model to GPU
    net.cuda()
    
    counter = 0

    net.train()

    for e in range(epochs):

        # initialize hidden state
        h = net.init_hidden(batch_size)
        
        for inputs, targets in train_loader:
            counter+= 1
            
            # push tensors to GPU
            inputs, targets = inputs.cuda(), targets.cuda()

            # detach hidden states
            h = tuple([each.data for each in h])

            # zero accumulated gradients
            net.zero_grad()
            
            # get the output from the model
            output, h = net(inputs, h)
            
            # calculate the loss and perform backprop
            loss = criterion(output, targets.view(-1))

            # back-propagate error
            loss.backward()

            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)

            # update weigths
            opt.step()            
            
            if counter % print_every == 0:
            
              print("Epoch: {}/{}...".format(e+1, epochs),
                    "Step: {}...".format(counter))

# %%
# Train the model
train(net, D, batch_size = 32, epochs=20, print_every=256)
torch.save(net.state_dict(), '/data-disk/rap/baseline.md')
# Out:
# Epoch: 1/20... Step: 256...
# Epoch: 1/20... Step: 512...
# Epoch: 1/20... Step: 768...
# Epoch: 1/20... Step: 1024...
# Epoch: 1/20... Step: 1280...
# Epoch: 1/20... Step: 1536...
# Epoch: 1/20... Step: 1792...
# Epoch: 1/20... Step: 2048...
# Epoch: 1/20... Step: 2304...
# Epoch: 1/20... Step: 2560...
# Epoch: 1/20... Step: 2816...
# Epoch: 1/20... Step: 3072...
# Epoch: 1/20... Step: 3328...
# Epoch: 1/20... Step: 3584...
# Epoch: 1/20... Step: 3840...
# Epoch: 1/20... Step: 4096...
# Epoch: 1/20... Step: 4352...
# Epoch: 1/20... Step: 4608...
# Epoch: 1/20... Step: 4864...
# Epoch: 1/20... Step: 5120...
# Epoch: 1/20... Step: 5376...
# Epoch: 1/20... Step: 5632...
# Epoch: 1/20... Step: 5888...
# Epoch: 1/20... Step: 6144...
# Epoch: 1/20... Step: 6400...
# Epoch: 1/20... Step: 6656...
# Epoch: 1/20... Step: 6912...
# Epoch: 1/20... Step: 7168...
# Epoch: 1/20... Step: 7424...
# Epoch: 1/20... Step: 7680...
# Epoch: 1/20... Step: 7936...
# Epoch: 1/20... Step: 8192...
# Epoch: 1/20... Step: 8448...
# Epoch: 1/20... Step: 8704...
# Epoch: 1/20... Step: 8960...
# Epoch: 1/20... Step: 9216...
# Epoch: 1/20... Step: 9472...
# Epoch: 1/20... Step: 9728...
# Epoch: 1/20... Step: 9984...
# Epoch: 1/20... Step: 10240...
# Epoch: 1/20... Step: 10496...
# Epoch: 1/20... Step: 10752...
# Epoch: 1/20... Step: 11008...
# Epoch: 1/20... Step: 11264...
# Epoch: 1/20... Step: 11520...
# Epoch: 1/20... Step: 11776...
# Epoch: 1/20... Step: 12032...
# Epoch: 1/20... Step: 12288...
# Epoch: 1/20... Step: 12544...
# Epoch: 1/20... Step: 12800...
# Epoch: 1/20... Step: 13056...
# Epoch: 1/20... Step: 13312...
# Epoch: 1/20... Step: 13568...
# Epoch: 1/20... Step: 13824...
# Epoch: 1/20... Step: 14080...
# Epoch: 1/20... Step: 14336...
# Epoch: 2/20... Step: 14592...
# Epoch: 2/20... Step: 14848...
# Epoch: 2/20... Step: 15104...
# Epoch: 2/20... Step: 15360...
# Epoch: 2/20... Step: 15616...
# Epoch: 2/20... Step: 15872...
# Epoch: 2/20... Step: 16128...
# Epoch: 2/20... Step: 16384...
# Epoch: 2/20... Step: 16640...
# Epoch: 2/20... Step: 16896...
# Epoch: 2/20... Step: 17152...
# Epoch: 2/20... Step: 17408...
# Epoch: 2/20... Step: 17664...
# Epoch: 2/20... Step: 17920...
# Epoch: 2/20... Step: 18176...
# Epoch: 2/20... Step: 18432...
# Epoch: 2/20... Step: 18688...
# Epoch: 2/20... Step: 18944...
# Epoch: 2/20... Step: 19200...
# Epoch: 2/20... Step: 19456...
# Epoch: 2/20... Step: 19712...
# Epoch: 2/20... Step: 19968...
# Epoch: 2/20... Step: 20224...
# Epoch: 2/20... Step: 20480...
# Epoch: 2/20... Step: 20736...
# Epoch: 2/20... Step: 20992...
# Epoch: 2/20... Step: 21248...
# Epoch: 2/20... Step: 21504...
# Epoch: 2/20... Step: 21760...
# Epoch: 2/20... Step: 22016...
# Epoch: 2/20... Step: 22272...
# Epoch: 2/20... Step: 22528...
# Epoch: 2/20... Step: 22784...
# Epoch: 2/20... Step: 23040...
# Epoch: 2/20... Step: 23296...
# Epoch: 2/20... Step: 23552...
# Epoch: 2/20... Step: 23808...
# Epoch: 2/20... Step: 24064...
# Epoch: 2/20... Step: 24320...
# Epoch: 2/20... Step: 24576...
# Epoch: 2/20... Step: 24832...
# Epoch: 2/20... Step: 25088...
# Epoch: 2/20... Step: 25344...
# Epoch: 2/20... Step: 25600...
# Epoch: 2/20... Step: 25856...
# Epoch: 2/20... Step: 26112...
# Epoch: 2/20... Step: 26368...
# Epoch: 2/20... Step: 26624...
# Epoch: 2/20... Step: 26880...
# Epoch: 2/20... Step: 27136...
# Epoch: 2/20... Step: 27392...
# Epoch: 2/20... Step: 27648...
# Epoch: 2/20... Step: 27904...
# Epoch: 2/20... Step: 28160...
# Epoch: 2/20... Step: 28416...
# Epoch: 2/20... Step: 28672...
# Epoch: 3/20... Step: 28928...
# Epoch: 3/20... Step: 29184...
# Epoch: 3/20... Step: 29440...
# Epoch: 3/20... Step: 29696...
# Epoch: 3/20... Step: 29952...
# Epoch: 3/20... Step: 30208...
# Epoch: 3/20... Step: 30464...
# Epoch: 3/20... Step: 30720...
# Epoch: 3/20... Step: 30976...
# Epoch: 3/20... Step: 31232...
# Epoch: 3/20... Step: 31488...
# Epoch: 3/20... Step: 31744...
# Epoch: 3/20... Step: 32000...
# Epoch: 3/20... Step: 32256...
# Epoch: 3/20... Step: 32512...
# Epoch: 3/20... Step: 32768...
# Epoch: 3/20... Step: 33024...
# Epoch: 3/20... Step: 33280...
# Epoch: 3/20... Step: 33536...
# Epoch: 3/20... Step: 33792...
# Epoch: 3/20... Step: 34048...
# Epoch: 3/20... Step: 34304...
# Epoch: 3/20... Step: 34560...
# Epoch: 3/20... Step: 34816...
# Epoch: 3/20... Step: 35072...
# Epoch: 3/20... Step: 35328...
# Epoch: 3/20... Step: 35584...
# Epoch: 3/20... Step: 35840...
# Epoch: 3/20... Step: 36096...
# Epoch: 3/20... Step: 36352...
# Epoch: 3/20... Step: 36608...
# Epoch: 3/20... Step: 36864...
# Epoch: 3/20... Step: 37120...
# Epoch: 3/20... Step: 37376...
# Epoch: 3/20... Step: 37632...
# Epoch: 3/20... Step: 37888...
# Epoch: 3/20... Step: 38144...
# Epoch: 3/20... Step: 38400...
# Epoch: 3/20... Step: 38656...
# Epoch: 3/20... Step: 38912...
# Epoch: 3/20... Step: 39168...
# Epoch: 3/20... Step: 39424...
# Epoch: 3/20... Step: 39680...
# Epoch: 3/20... Step: 39936...
# Epoch: 3/20... Step: 40192...
# Epoch: 3/20... Step: 40448...
# Epoch: 3/20... Step: 40704...
# Epoch: 3/20... Step: 40960...
# Epoch: 3/20... Step: 41216...
# Epoch: 3/20... Step: 41472...
# Epoch: 3/20... Step: 41728...
# Epoch: 3/20... Step: 41984...
# Epoch: 3/20... Step: 42240...
# Epoch: 3/20... Step: 42496...
# Epoch: 3/20... Step: 42752...
# Epoch: 3/20... Step: 43008...
# Epoch: 4/20... Step: 43264...
# Epoch: 4/20... Step: 43520...
# Epoch: 4/20... Step: 43776...
# Epoch: 4/20... Step: 44032...
# Epoch: 4/20... Step: 44288...
# Epoch: 4/20... Step: 44544...
# Epoch: 4/20... Step: 44800...
# Epoch: 4/20... Step: 45056...
# Epoch: 4/20... Step: 45312...
# Epoch: 4/20... Step: 45568...
# Epoch: 4/20... Step: 45824...
# Epoch: 4/20... Step: 46080...
# Epoch: 4/20... Step: 46336...
# Epoch: 4/20... Step: 46592...
# Epoch: 4/20... Step: 46848...
# Epoch: 4/20... Step: 47104...
# Epoch: 4/20... Step: 47360...
# Epoch: 4/20... Step: 47616...
# Epoch: 4/20... Step: 47872...
# Epoch: 4/20... Step: 48128...
# Epoch: 4/20... Step: 48384...
# Epoch: 4/20... Step: 48640...
# Epoch: 4/20... Step: 48896...
# Epoch: 4/20... Step: 49152...
# Epoch: 4/20... Step: 49408...
# Epoch: 4/20... Step: 49664...
# Epoch: 4/20... Step: 49920...
# Epoch: 4/20... Step: 50176...
# Epoch: 4/20... Step: 50432...
# Epoch: 4/20... Step: 50688...
# Epoch: 4/20... Step: 50944...
# Epoch: 4/20... Step: 51200...
# Epoch: 4/20... Step: 51456...
# Epoch: 4/20... Step: 51712...
# Epoch: 4/20... Step: 51968...
# Epoch: 4/20... Step: 52224...
# Epoch: 4/20... Step: 52480...
# Epoch: 4/20... Step: 52736...
# Epoch: 4/20... Step: 52992...
# Epoch: 4/20... Step: 53248...
# Epoch: 4/20... Step: 53504...
# Epoch: 4/20... Step: 53760...
# Epoch: 4/20... Step: 54016...
# Epoch: 4/20... Step: 54272...
# Epoch: 4/20... Step: 54528...
# Epoch: 4/20... Step: 54784...
# Epoch: 4/20... Step: 55040...
# Epoch: 4/20... Step: 55296...
# Epoch: 4/20... Step: 55552...
# Epoch: 4/20... Step: 55808...
# Epoch: 4/20... Step: 56064...
# Epoch: 4/20... Step: 56320...
# Epoch: 4/20... Step: 56576...
# Epoch: 4/20... Step: 56832...
# Epoch: 4/20... Step: 57088...
# Epoch: 4/20... Step: 57344...
# Epoch: 4/20... Step: 57600...
# Epoch: 5/20... Step: 57856...
# Epoch: 5/20... Step: 58112...
# Epoch: 5/20... Step: 58368...
# Epoch: 5/20... Step: 58624...
# Epoch: 5/20... Step: 58880...
# Epoch: 5/20... Step: 59136...
# Epoch: 5/20... Step: 59392...
# Epoch: 5/20... Step: 59648...
# Epoch: 5/20... Step: 59904...
# Epoch: 5/20... Step: 60160...
# Epoch: 5/20... Step: 60416...
# Epoch: 5/20... Step: 60672...
# Epoch: 5/20... Step: 60928...
# Epoch: 5/20... Step: 61184...
# Epoch: 5/20... Step: 61440...
# Epoch: 5/20... Step: 61696...
# Epoch: 5/20... Step: 61952...
# Epoch: 5/20... Step: 62208...
# Epoch: 5/20... Step: 62464...
# Epoch: 5/20... Step: 62720...
# Epoch: 5/20... Step: 62976...
# Epoch: 5/20... Step: 63232...
# Epoch: 5/20... Step: 63488...
# Epoch: 5/20... Step: 63744...
# Epoch: 5/20... Step: 64000...
# Epoch: 5/20... Step: 64256...
# Epoch: 5/20... Step: 64512...
# Epoch: 5/20... Step: 64768...
# Epoch: 5/20... Step: 65024...
# Epoch: 5/20... Step: 65280...
# Epoch: 5/20... Step: 65536...
# Epoch: 5/20... Step: 65792...
# Epoch: 5/20... Step: 66048...
# Epoch: 5/20... Step: 66304...
# Epoch: 5/20... Step: 66560...
# Epoch: 5/20... Step: 66816...
# Epoch: 5/20... Step: 67072...
# Epoch: 5/20... Step: 67328...
# Epoch: 5/20... Step: 67584...
# Epoch: 5/20... Step: 67840...
# Epoch: 5/20... Step: 68096...
# Epoch: 5/20... Step: 68352...
# Epoch: 5/20... Step: 68608...
# Epoch: 5/20... Step: 68864...
# Epoch: 5/20... Step: 69120...
# Epoch: 5/20... Step: 69376...
# Epoch: 5/20... Step: 69632...
# Epoch: 5/20... Step: 69888...
# Epoch: 5/20... Step: 70144...
# Epoch: 5/20... Step: 70400...
# Epoch: 5/20... Step: 70656...
# Epoch: 5/20... Step: 70912...
# Epoch: 5/20... Step: 71168...
# Epoch: 5/20... Step: 71424...
# Epoch: 5/20... Step: 71680...
# Epoch: 5/20... Step: 71936...
# Epoch: 6/20... Step: 72192...
# Epoch: 6/20... Step: 72448...
# Epoch: 6/20... Step: 72704...
# Epoch: 6/20... Step: 72960...
# Epoch: 6/20... Step: 73216...
# Epoch: 6/20... Step: 73472...
# Epoch: 6/20... Step: 73728...
# Epoch: 6/20... Step: 73984...
# Epoch: 6/20... Step: 74240...
# Epoch: 6/20... Step: 74496...
# Epoch: 6/20... Step: 74752...
# Epoch: 6/20... Step: 75008...
# Epoch: 6/20... Step: 75264...
# Epoch: 6/20... Step: 75520...
# Epoch: 6/20... Step: 75776...
# Epoch: 6/20... Step: 76032...
# Epoch: 6/20... Step: 76288...
# Epoch: 6/20... Step: 76544...
# Epoch: 6/20... Step: 76800...
# Epoch: 6/20... Step: 77056...
# Epoch: 6/20... Step: 77312...
# Epoch: 6/20... Step: 77568...
# Epoch: 6/20... Step: 77824...
# Epoch: 6/20... Step: 78080...
# Epoch: 6/20... Step: 78336...
# Epoch: 6/20... Step: 78592...
# Epoch: 6/20... Step: 78848...
# Epoch: 6/20... Step: 79104...
# Epoch: 6/20... Step: 79360...
# Epoch: 6/20... Step: 79616...
# Epoch: 6/20... Step: 79872...
# Epoch: 6/20... Step: 80128...
# Epoch: 6/20... Step: 80384...
# Epoch: 6/20... Step: 80640...
# Epoch: 6/20... Step: 80896...
# Epoch: 6/20... Step: 81152...
# Epoch: 6/20... Step: 81408...
# Epoch: 6/20... Step: 81664...
# Epoch: 6/20... Step: 81920...
# Epoch: 6/20... Step: 82176...
# Epoch: 6/20... Step: 82432...
# Epoch: 6/20... Step: 82688...
# Epoch: 6/20... Step: 82944...
# Epoch: 6/20... Step: 83200...
# Epoch: 6/20... Step: 83456...
# Epoch: 6/20... Step: 83712...
# Epoch: 6/20... Step: 83968...
# Epoch: 6/20... Step: 84224...
# Epoch: 6/20... Step: 84480...
# Epoch: 6/20... Step: 84736...
# Epoch: 6/20... Step: 84992...
# Epoch: 6/20... Step: 85248...
# Epoch: 6/20... Step: 85504...
# Epoch: 6/20... Step: 85760...
# Epoch: 6/20... Step: 86016...
# Epoch: 6/20... Step: 86272...
# Epoch: 7/20... Step: 86528...
# Epoch: 7/20... Step: 86784...
# Epoch: 7/20... Step: 87040...
# Epoch: 7/20... Step: 87296...
# Epoch: 7/20... Step: 87552...
# Epoch: 7/20... Step: 87808...
# Epoch: 7/20... Step: 88064...
# Epoch: 7/20... Step: 88320...
# Epoch: 7/20... Step: 88576...
# Epoch: 7/20... Step: 88832...
# Epoch: 7/20... Step: 89088...
# Epoch: 7/20... Step: 89344...
# Epoch: 7/20... Step: 89600...
# Epoch: 7/20... Step: 89856...
# Epoch: 7/20... Step: 90112...
# Epoch: 7/20... Step: 90368...
# Epoch: 7/20... Step: 90624...
# Epoch: 7/20... Step: 90880...
# Epoch: 7/20... Step: 91136...
# Epoch: 7/20... Step: 91392...
# Epoch: 7/20... Step: 91648...
# Epoch: 7/20... Step: 91904...
# Epoch: 7/20... Step: 92160...
# Epoch: 7/20... Step: 92416...
# Epoch: 7/20... Step: 92672...
# Epoch: 7/20... Step: 92928...
# Epoch: 7/20... Step: 93184...
# Epoch: 7/20... Step: 93440...
# Epoch: 7/20... Step: 93696...
# Epoch: 7/20... Step: 93952...
# Epoch: 7/20... Step: 94208...
# Epoch: 7/20... Step: 94464...
# Epoch: 7/20... Step: 94720...
# Epoch: 7/20... Step: 94976...
# Epoch: 7/20... Step: 95232...
# Epoch: 7/20... Step: 95488...
# Epoch: 7/20... Step: 95744...
# Epoch: 7/20... Step: 96000...
# Epoch: 7/20... Step: 96256...
# Epoch: 7/20... Step: 96512...
# Epoch: 7/20... Step: 96768...
# Epoch: 7/20... Step: 97024...
# Epoch: 7/20... Step: 97280...
# Epoch: 7/20... Step: 97536...
# Epoch: 7/20... Step: 97792...
# Epoch: 7/20... Step: 98048...
# Epoch: 7/20... Step: 98304...
# Epoch: 7/20... Step: 98560...
# Epoch: 7/20... Step: 98816...
# Epoch: 7/20... Step: 99072...
# Epoch: 7/20... Step: 99328...
# Epoch: 7/20... Step: 99584...
# Epoch: 7/20... Step: 99840...
# Epoch: 7/20... Step: 100096...
# Epoch: 7/20... Step: 100352...
# Epoch: 7/20... Step: 100608...
# Epoch: 8/20... Step: 100864...
# Epoch: 8/20... Step: 101120...
# Epoch: 8/20... Step: 101376...
# Epoch: 8/20... Step: 101632...
# Epoch: 8/20... Step: 101888...
# Epoch: 8/20... Step: 102144...
# Epoch: 8/20... Step: 102400...
# Epoch: 8/20... Step: 102656...
# Epoch: 8/20... Step: 102912...
# Epoch: 8/20... Step: 103168...
# Epoch: 8/20... Step: 103424...
# Epoch: 8/20... Step: 103680...
# Epoch: 8/20... Step: 103936...
# Epoch: 8/20... Step: 104192...
# Epoch: 8/20... Step: 104448...
# Epoch: 8/20... Step: 104704...
# Epoch: 8/20... Step: 104960...
# Epoch: 8/20... Step: 105216...
# Epoch: 8/20... Step: 105472...
# Epoch: 8/20... Step: 105728...
# Epoch: 8/20... Step: 105984...
# Epoch: 8/20... Step: 106240...
# Epoch: 8/20... Step: 106496...
# Epoch: 8/20... Step: 106752...
# Epoch: 8/20... Step: 107008...
# Epoch: 8/20... Step: 107264...
# Epoch: 8/20... Step: 107520...
# Epoch: 8/20... Step: 107776...
# Epoch: 8/20... Step: 108032...
# Epoch: 8/20... Step: 108288...
# Epoch: 8/20... Step: 108544...
# Epoch: 8/20... Step: 108800...
# Epoch: 8/20... Step: 109056...
# Epoch: 8/20... Step: 109312...
# Epoch: 8/20... Step: 109568...
# Epoch: 8/20... Step: 109824...
# Epoch: 8/20... Step: 110080...
# Epoch: 8/20... Step: 110336...
# Epoch: 8/20... Step: 110592...
# Epoch: 8/20... Step: 110848...
# Epoch: 8/20... Step: 111104...
# Epoch: 8/20... Step: 111360...
# Epoch: 8/20... Step: 111616...
# Epoch: 8/20... Step: 111872...
# Epoch: 8/20... Step: 112128...
# Epoch: 8/20... Step: 112384...
# Epoch: 8/20... Step: 112640...
# Epoch: 8/20... Step: 112896...
# Epoch: 8/20... Step: 113152...
# Epoch: 8/20... Step: 113408...
# Epoch: 8/20... Step: 113664...
# Epoch: 8/20... Step: 113920...
# Epoch: 8/20... Step: 114176...
# Epoch: 8/20... Step: 114432...
# Epoch: 8/20... Step: 114688...
# Epoch: 8/20... Step: 114944...
# Epoch: 8/20... Step: 115200...
# Epoch: 9/20... Step: 115456...
# Epoch: 9/20... Step: 115712...
# Epoch: 9/20... Step: 115968...
# Epoch: 9/20... Step: 116224...
# Epoch: 9/20... Step: 116480...
# Epoch: 9/20... Step: 116736...
# Epoch: 9/20... Step: 116992...
# Epoch: 9/20... Step: 117248...
# Epoch: 9/20... Step: 117504...
# Epoch: 9/20... Step: 117760...
# Epoch: 9/20... Step: 118016...
# Epoch: 9/20... Step: 118272...
# Epoch: 9/20... Step: 118528...
# Epoch: 9/20... Step: 118784...
# Epoch: 9/20... Step: 119040...
# Epoch: 9/20... Step: 119296...
# Epoch: 9/20... Step: 119552...
# Epoch: 9/20... Step: 119808...
# Epoch: 9/20... Step: 120064...
# Epoch: 9/20... Step: 120320...
# Epoch: 9/20... Step: 120576...
# Epoch: 9/20... Step: 120832...
# Epoch: 9/20... Step: 121088...
# Epoch: 9/20... Step: 121344...
# Epoch: 9/20... Step: 121600...
# Epoch: 9/20... Step: 121856...
# Epoch: 9/20... Step: 122112...
# Epoch: 9/20... Step: 122368...
# Epoch: 9/20... Step: 122624...
# Epoch: 9/20... Step: 122880...
# Epoch: 9/20... Step: 123136...
# Epoch: 9/20... Step: 123392...
# Epoch: 9/20... Step: 123648...
# Epoch: 9/20... Step: 123904...
# Epoch: 9/20... Step: 124160...
# Epoch: 9/20... Step: 124416...
# Epoch: 9/20... Step: 124672...
# Epoch: 9/20... Step: 124928...
# Epoch: 9/20... Step: 125184...
# Epoch: 9/20... Step: 125440...
# Epoch: 9/20... Step: 125696...
# Epoch: 9/20... Step: 125952...
# Epoch: 9/20... Step: 126208...
# Epoch: 9/20... Step: 126464...
# Epoch: 9/20... Step: 126720...
# Epoch: 9/20... Step: 126976...
# Epoch: 9/20... Step: 127232...
# Epoch: 9/20... Step: 127488...
# Epoch: 9/20... Step: 127744...
# Epoch: 9/20... Step: 128000...
# Epoch: 9/20... Step: 128256...
# Epoch: 9/20... Step: 128512...
# Epoch: 9/20... Step: 128768...
# Epoch: 9/20... Step: 129024...
# Epoch: 9/20... Step: 129280...
# Epoch: 9/20... Step: 129536...
# Epoch: 10/20... Step: 129792...
# Epoch: 10/20... Step: 130048...
# Epoch: 10/20... Step: 130304...
# Epoch: 10/20... Step: 130560...
# Epoch: 10/20... Step: 130816...
# Epoch: 10/20... Step: 131072...
# Epoch: 10/20... Step: 131328...
# Epoch: 10/20... Step: 131584...
# Epoch: 10/20... Step: 131840...
# Epoch: 10/20... Step: 132096...
# Epoch: 10/20... Step: 132352...
# Epoch: 10/20... Step: 132608...
# Epoch: 10/20... Step: 132864...
# Epoch: 10/20... Step: 133120...
# Epoch: 10/20... Step: 133376...
# Epoch: 10/20... Step: 133632...
# Epoch: 10/20... Step: 133888...
# Epoch: 10/20... Step: 134144...
# Epoch: 10/20... Step: 134400...
# Epoch: 10/20... Step: 134656...
# Epoch: 10/20... Step: 134912...
# Epoch: 10/20... Step: 135168...
# Epoch: 10/20... Step: 135424...
# Epoch: 10/20... Step: 135680...
# Epoch: 10/20... Step: 135936...
# Epoch: 10/20... Step: 136192...
# Epoch: 10/20... Step: 136448...
# Epoch: 10/20... Step: 136704...
# Epoch: 10/20... Step: 136960...
# Epoch: 10/20... Step: 137216...
# Epoch: 10/20... Step: 137472...
# Epoch: 10/20... Step: 137728...
# Epoch: 10/20... Step: 137984...
# Epoch: 10/20... Step: 138240...
# Epoch: 10/20... Step: 138496...
# Epoch: 10/20... Step: 138752...
# Epoch: 10/20... Step: 139008...
# Epoch: 10/20... Step: 139264...
# Epoch: 10/20... Step: 139520...
# Epoch: 10/20... Step: 139776...
# Epoch: 10/20... Step: 140032...
# Epoch: 10/20... Step: 140288...
# Epoch: 10/20... Step: 140544...
# Epoch: 10/20... Step: 140800...
# Epoch: 10/20... Step: 141056...
# Epoch: 10/20... Step: 141312...
# Epoch: 10/20... Step: 141568...
# Epoch: 10/20... Step: 141824...
# Epoch: 10/20... Step: 142080...
# Epoch: 10/20... Step: 142336...
# Epoch: 10/20... Step: 142592...
# Epoch: 10/20... Step: 142848...
# Epoch: 10/20... Step: 143104...
# Epoch: 10/20... Step: 143360...
# Epoch: 10/20... Step: 143616...
# Epoch: 10/20... Step: 143872...
# Epoch: 11/20... Step: 144128...
# Epoch: 11/20... Step: 144384...
# Epoch: 11/20... Step: 144640...
# Epoch: 11/20... Step: 144896...
# Epoch: 11/20... Step: 145152...
# Epoch: 11/20... Step: 145408...
# Epoch: 11/20... Step: 145664...
# Epoch: 11/20... Step: 145920...
# Epoch: 11/20... Step: 146176...
# Epoch: 11/20... Step: 146432...
# Epoch: 11/20... Step: 146688...
# Epoch: 11/20... Step: 146944...
# Epoch: 11/20... Step: 147200...
# Epoch: 11/20... Step: 147456...
# Epoch: 11/20... Step: 147712...
# Epoch: 11/20... Step: 147968...
# Epoch: 11/20... Step: 148224...
# Epoch: 11/20... Step: 148480...
# Epoch: 11/20... Step: 148736...
# Epoch: 11/20... Step: 148992...
# Epoch: 11/20... Step: 149248...
# Epoch: 11/20... Step: 149504...
# Epoch: 11/20... Step: 149760...
# Epoch: 11/20... Step: 150016...
# Epoch: 11/20... Step: 150272...
# Epoch: 11/20... Step: 150528...
# Epoch: 11/20... Step: 150784...
# Epoch: 11/20... Step: 151040...
# Epoch: 11/20... Step: 151296...
# Epoch: 11/20... Step: 151552...
# Epoch: 11/20... Step: 151808...
# Epoch: 11/20... Step: 152064...
# Epoch: 11/20... Step: 152320...
# Epoch: 11/20... Step: 152576...
# Epoch: 11/20... Step: 152832...
# Epoch: 11/20... Step: 153088...
# Epoch: 11/20... Step: 153344...
# Epoch: 11/20... Step: 153600...
# Epoch: 11/20... Step: 153856...
# Epoch: 11/20... Step: 154112...
# Epoch: 11/20... Step: 154368...
# Epoch: 11/20... Step: 154624...
# Epoch: 11/20... Step: 154880...
# Epoch: 11/20... Step: 155136...
# Epoch: 11/20... Step: 155392...
# Epoch: 11/20... Step: 155648...
# Epoch: 11/20... Step: 155904...
# Epoch: 11/20... Step: 156160...
# Epoch: 11/20... Step: 156416...
# Epoch: 11/20... Step: 156672...
# Epoch: 11/20... Step: 156928...
# Epoch: 11/20... Step: 157184...
# Epoch: 11/20... Step: 157440...
# Epoch: 11/20... Step: 157696...
# Epoch: 11/20... Step: 157952...
# Epoch: 11/20... Step: 158208...
# Epoch: 12/20... Step: 158464...
# Epoch: 12/20... Step: 158720...
# Epoch: 12/20... Step: 158976...
# Epoch: 12/20... Step: 159232...
# Epoch: 12/20... Step: 159488...
# Epoch: 12/20... Step: 159744...
# Epoch: 12/20... Step: 160000...
# Epoch: 12/20... Step: 160256...
# Epoch: 12/20... Step: 160512...
# Epoch: 12/20... Step: 160768...
# Epoch: 12/20... Step: 161024...
# Epoch: 12/20... Step: 161280...
# Epoch: 12/20... Step: 161536...
# Epoch: 12/20... Step: 161792...
# Epoch: 12/20... Step: 162048...
# Epoch: 12/20... Step: 162304...
# Epoch: 12/20... Step: 162560...
# Epoch: 12/20... Step: 162816...
# Epoch: 12/20... Step: 163072...
# Epoch: 12/20... Step: 163328...
# Epoch: 12/20... Step: 163584...
# Epoch: 12/20... Step: 163840...
# Epoch: 12/20... Step: 164096...
# Epoch: 12/20... Step: 164352...
# Epoch: 12/20... Step: 164608...
# Epoch: 12/20... Step: 164864...
# Epoch: 12/20... Step: 165120...
# Epoch: 12/20... Step: 165376...
# Epoch: 12/20... Step: 165632...
# Epoch: 12/20... Step: 165888...
# Epoch: 12/20... Step: 166144...
# Epoch: 12/20... Step: 166400...
# Epoch: 12/20... Step: 166656...
# Epoch: 12/20... Step: 166912...
# Epoch: 12/20... Step: 167168...
# Epoch: 12/20... Step: 167424...
# Epoch: 12/20... Step: 167680...
# Epoch: 12/20... Step: 167936...
# Epoch: 12/20... Step: 168192...
# Epoch: 12/20... Step: 168448...
# Epoch: 12/20... Step: 168704...
# Epoch: 12/20... Step: 168960...
# Epoch: 12/20... Step: 169216...
# Epoch: 12/20... Step: 169472...
# Epoch: 12/20... Step: 169728...
# Epoch: 12/20... Step: 169984...
# Epoch: 12/20... Step: 170240...
# Epoch: 12/20... Step: 170496...
# Epoch: 12/20... Step: 170752...
# Epoch: 12/20... Step: 171008...
# Epoch: 12/20... Step: 171264...
# Epoch: 12/20... Step: 171520...
# Epoch: 12/20... Step: 171776...
# Epoch: 12/20... Step: 172032...
# Epoch: 12/20... Step: 172288...
# Epoch: 12/20... Step: 172544...
# Epoch: 12/20... Step: 172800...
# Epoch: 13/20... Step: 173056...
# Epoch: 13/20... Step: 173312...
# Epoch: 13/20... Step: 173568...
# Epoch: 13/20... Step: 173824...
# Epoch: 13/20... Step: 174080...
# Epoch: 13/20... Step: 174336...
# Epoch: 13/20... Step: 174592...
# Epoch: 13/20... Step: 174848...
# Epoch: 13/20... Step: 175104...
# Epoch: 13/20... Step: 175360...
# Epoch: 13/20... Step: 175616...
# Epoch: 13/20... Step: 175872...
# Epoch: 13/20... Step: 176128...
# Epoch: 13/20... Step: 176384...
# Epoch: 13/20... Step: 176640...
# Epoch: 13/20... Step: 176896...
# Epoch: 13/20... Step: 177152...
# Epoch: 13/20... Step: 177408...
# Epoch: 13/20... Step: 177664...
# Epoch: 13/20... Step: 177920...
# Epoch: 13/20... Step: 178176...
# Epoch: 13/20... Step: 178432...
# Epoch: 13/20... Step: 178688...
# Epoch: 13/20... Step: 178944...
# Epoch: 13/20... Step: 179200...
# Epoch: 13/20... Step: 179456...
# Epoch: 13/20... Step: 179712...
# Epoch: 13/20... Step: 179968...
# Epoch: 13/20... Step: 180224...
# Epoch: 13/20... Step: 180480...
# Epoch: 13/20... Step: 180736...
# Epoch: 13/20... Step: 180992...
# Epoch: 13/20... Step: 181248...
# Epoch: 13/20... Step: 181504...
# Epoch: 13/20... Step: 181760...
# Epoch: 13/20... Step: 182016...
# Epoch: 13/20... Step: 182272...
# Epoch: 13/20... Step: 182528...
# Epoch: 13/20... Step: 182784...
# Epoch: 13/20... Step: 183040...
# Epoch: 13/20... Step: 183296...
# Epoch: 13/20... Step: 183552...
# Epoch: 13/20... Step: 183808...
# Epoch: 13/20... Step: 184064...
# Epoch: 13/20... Step: 184320...
# Epoch: 13/20... Step: 184576...
# Epoch: 13/20... Step: 184832...
# Epoch: 13/20... Step: 185088...
# Epoch: 13/20... Step: 185344...
# Epoch: 13/20... Step: 185600...
# Epoch: 13/20... Step: 185856...
# Epoch: 13/20... Step: 186112...
# Epoch: 13/20... Step: 186368...
# Epoch: 13/20... Step: 186624...
# Epoch: 13/20... Step: 186880...
# Epoch: 13/20... Step: 187136...
# Epoch: 14/20... Step: 187392...
# Epoch: 14/20... Step: 187648...
# Epoch: 14/20... Step: 187904...
# Epoch: 14/20... Step: 188160...
# Epoch: 14/20... Step: 188416...
# Epoch: 14/20... Step: 188672...
# Epoch: 14/20... Step: 188928...
# Epoch: 14/20... Step: 189184...
# Epoch: 14/20... Step: 189440...
# Epoch: 14/20... Step: 189696...
# Epoch: 14/20... Step: 189952...
# Epoch: 14/20... Step: 190208...
# Epoch: 14/20... Step: 190464...
# Epoch: 14/20... Step: 190720...
# Epoch: 14/20... Step: 190976...
# Epoch: 14/20... Step: 191232...
# Epoch: 14/20... Step: 191488...
# Epoch: 14/20... Step: 191744...
# Epoch: 14/20... Step: 192000...
# Epoch: 14/20... Step: 192256...
# Epoch: 14/20... Step: 192512...
# Epoch: 14/20... Step: 192768...
# Epoch: 14/20... Step: 193024...
# Epoch: 14/20... Step: 193280...
# Epoch: 14/20... Step: 193536...
# Epoch: 14/20... Step: 193792...
# Epoch: 14/20... Step: 194048...
# Epoch: 14/20... Step: 194304...
# Epoch: 14/20... Step: 194560...
# Epoch: 14/20... Step: 194816...
# Epoch: 14/20... Step: 195072...
# Epoch: 14/20... Step: 195328...
# Epoch: 14/20... Step: 195584...
# Epoch: 14/20... Step: 195840...
# Epoch: 14/20... Step: 196096...
# Epoch: 14/20... Step: 196352...
# Epoch: 14/20... Step: 196608...
# Epoch: 14/20... Step: 196864...
# Epoch: 14/20... Step: 197120...
# Epoch: 14/20... Step: 197376...
# Epoch: 14/20... Step: 197632...
# Epoch: 14/20... Step: 197888...
# Epoch: 14/20... Step: 198144...
# Epoch: 14/20... Step: 198400...
# Epoch: 14/20... Step: 198656...
# Epoch: 14/20... Step: 198912...
# Epoch: 14/20... Step: 199168...
# Epoch: 14/20... Step: 199424...
# Epoch: 14/20... Step: 199680...
# Epoch: 14/20... Step: 199936...
# Epoch: 14/20... Step: 200192...
# Epoch: 14/20... Step: 200448...
# Epoch: 14/20... Step: 200704...
# Epoch: 14/20... Step: 200960...
# Epoch: 14/20... Step: 201216...
# Epoch: 14/20... Step: 201472...
# Epoch: 15/20... Step: 201728...
# Epoch: 15/20... Step: 201984...
# Epoch: 15/20... Step: 202240...
# Epoch: 15/20... Step: 202496...
# Epoch: 15/20... Step: 202752...
# Epoch: 15/20... Step: 203008...
# Epoch: 15/20... Step: 203264...
# Epoch: 15/20... Step: 203520...
# Epoch: 15/20... Step: 203776...
# Epoch: 15/20... Step: 204032...
# Epoch: 15/20... Step: 204288...
# Epoch: 15/20... Step: 204544...
# Epoch: 15/20... Step: 204800...
# Epoch: 15/20... Step: 205056...
# Epoch: 15/20... Step: 205312...
# Epoch: 15/20... Step: 205568...
# Epoch: 15/20... Step: 205824...
# Epoch: 15/20... Step: 206080...
# Epoch: 15/20... Step: 206336...
# Epoch: 15/20... Step: 206592...
# Epoch: 15/20... Step: 206848...
# Epoch: 15/20... Step: 207104...
# Epoch: 15/20... Step: 207360...
# Epoch: 15/20... Step: 207616...
# Epoch: 15/20... Step: 207872...
# Epoch: 15/20... Step: 208128...
# Epoch: 15/20... Step: 208384...
# Epoch: 15/20... Step: 208640...
# Epoch: 15/20... Step: 208896...
# Epoch: 15/20... Step: 209152...
# Epoch: 15/20... Step: 209408...
# Epoch: 15/20... Step: 209664...
# Epoch: 15/20... Step: 209920...
# Epoch: 15/20... Step: 210176...
# Epoch: 15/20... Step: 210432...
# Epoch: 15/20... Step: 210688...
# Epoch: 15/20... Step: 210944...
# Epoch: 15/20... Step: 211200...
# Epoch: 15/20... Step: 211456...
# Epoch: 15/20... Step: 211712...
# Epoch: 15/20... Step: 211968...
# Epoch: 15/20... Step: 212224...
# Epoch: 15/20... Step: 212480...
# Epoch: 15/20... Step: 212736...
# Epoch: 15/20... Step: 212992...
# Epoch: 15/20... Step: 213248...
# Epoch: 15/20... Step: 213504...
# Epoch: 15/20... Step: 213760...
# Epoch: 15/20... Step: 214016...
# Epoch: 15/20... Step: 214272...
# Epoch: 15/20... Step: 214528...
# Epoch: 15/20... Step: 214784...
# Epoch: 15/20... Step: 215040...
# Epoch: 15/20... Step: 215296...
# Epoch: 15/20... Step: 215552...
# Epoch: 15/20... Step: 215808...
# Epoch: 16/20... Step: 216064...
# Epoch: 16/20... Step: 216320...
# Epoch: 16/20... Step: 216576...
# Epoch: 16/20... Step: 216832...
# Epoch: 16/20... Step: 217088...
# Epoch: 16/20... Step: 217344...
# Epoch: 16/20... Step: 217600...
# Epoch: 16/20... Step: 217856...
# Epoch: 16/20... Step: 218112...
# Epoch: 16/20... Step: 218368...
# Epoch: 16/20... Step: 218624...
# Epoch: 16/20... Step: 218880...
# Epoch: 16/20... Step: 219136...
# Epoch: 16/20... Step: 219392...
# Epoch: 16/20... Step: 219648...
# Epoch: 16/20... Step: 219904...
# Epoch: 16/20... Step: 220160...
# Epoch: 16/20... Step: 220416...
# Epoch: 16/20... Step: 220672...
# Epoch: 16/20... Step: 220928...
# Epoch: 16/20... Step: 221184...
# Epoch: 16/20... Step: 221440...
# Epoch: 16/20... Step: 221696...
# Epoch: 16/20... Step: 221952...
# Epoch: 16/20... Step: 222208...
# Epoch: 16/20... Step: 222464...
# Epoch: 16/20... Step: 222720...
# Epoch: 16/20... Step: 222976...
# Epoch: 16/20... Step: 223232...
# Epoch: 16/20... Step: 223488...
# Epoch: 16/20... Step: 223744...
# Epoch: 16/20... Step: 224000...
# Epoch: 16/20... Step: 224256...
# Epoch: 16/20... Step: 224512...
# Epoch: 16/20... Step: 224768...
# Epoch: 16/20... Step: 225024...
# Epoch: 16/20... Step: 225280...
# Epoch: 16/20... Step: 225536...
# Epoch: 16/20... Step: 225792...
# Epoch: 16/20... Step: 226048...
# Epoch: 16/20... Step: 226304...
# Epoch: 16/20... Step: 226560...
# Epoch: 16/20... Step: 226816...
# Epoch: 16/20... Step: 227072...
# Epoch: 16/20... Step: 227328...
# Epoch: 16/20... Step: 227584...
# Epoch: 16/20... Step: 227840...
# Epoch: 16/20... Step: 228096...
# Epoch: 16/20... Step: 228352...
# Epoch: 16/20... Step: 228608...
# Epoch: 16/20... Step: 228864...
# Epoch: 16/20... Step: 229120...
# Epoch: 16/20... Step: 229376...
# Epoch: 16/20... Step: 229632...
# Epoch: 16/20... Step: 229888...
# Epoch: 16/20... Step: 230144...
# Epoch: 16/20... Step: 230400...
# Epoch: 17/20... Step: 230656...
# Epoch: 17/20... Step: 230912...
# Epoch: 17/20... Step: 231168...
# Epoch: 17/20... Step: 231424...
# Epoch: 17/20... Step: 231680...
# Epoch: 17/20... Step: 231936...
# Epoch: 17/20... Step: 232192...
# Epoch: 17/20... Step: 232448...
# Epoch: 17/20... Step: 232704...
# Epoch: 17/20... Step: 232960...
# Epoch: 17/20... Step: 233216...
# Epoch: 17/20... Step: 233472...
# Epoch: 17/20... Step: 233728...
# Epoch: 17/20... Step: 233984...
# Epoch: 17/20... Step: 234240...
# Epoch: 17/20... Step: 234496...
# Epoch: 17/20... Step: 234752...
# Epoch: 17/20... Step: 235008...
# Epoch: 17/20... Step: 235264...
# Epoch: 17/20... Step: 235520...
# Epoch: 17/20... Step: 235776...
# Epoch: 17/20... Step: 236032...
# Epoch: 17/20... Step: 236288...
# Epoch: 17/20... Step: 236544...
# Epoch: 17/20... Step: 236800...
# Epoch: 17/20... Step: 237056...
# Epoch: 17/20... Step: 237312...
# Epoch: 17/20... Step: 237568...
# Epoch: 17/20... Step: 237824...
# Epoch: 17/20... Step: 238080...
# Epoch: 17/20... Step: 238336...
# Epoch: 17/20... Step: 238592...
# Epoch: 17/20... Step: 238848...
# Epoch: 17/20... Step: 239104...
# Epoch: 17/20... Step: 239360...
# Epoch: 17/20... Step: 239616...
# Epoch: 17/20... Step: 239872...
# Epoch: 17/20... Step: 240128...
# Epoch: 17/20... Step: 240384...
# Epoch: 17/20... Step: 240640...
# Epoch: 17/20... Step: 240896...
# Epoch: 17/20... Step: 241152...
# Epoch: 17/20... Step: 241408...
# Epoch: 17/20... Step: 241664...
# Epoch: 17/20... Step: 241920...
# Epoch: 17/20... Step: 242176...
# Epoch: 17/20... Step: 242432...
# Epoch: 17/20... Step: 242688...
# Epoch: 17/20... Step: 242944...
# Epoch: 17/20... Step: 243200...
# Epoch: 17/20... Step: 243456...
# Epoch: 17/20... Step: 243712...
# Epoch: 17/20... Step: 243968...
# Epoch: 17/20... Step: 244224...
# Epoch: 17/20... Step: 244480...
# Epoch: 17/20... Step: 244736...
# Epoch: 18/20... Step: 244992...
# Epoch: 18/20... Step: 245248...
# Epoch: 18/20... Step: 245504...
# Epoch: 18/20... Step: 245760...
# Epoch: 18/20... Step: 246016...
# Epoch: 18/20... Step: 246272...
# Epoch: 18/20... Step: 246528...
# Epoch: 18/20... Step: 246784...
# Epoch: 18/20... Step: 247040...
# Epoch: 18/20... Step: 247296...
# Epoch: 18/20... Step: 247552...
# Epoch: 18/20... Step: 247808...
# Epoch: 18/20... Step: 248064...
# Epoch: 18/20... Step: 248320...
# Epoch: 18/20... Step: 248576...
# Epoch: 18/20... Step: 248832...
# Epoch: 18/20... Step: 249088...
# Epoch: 18/20... Step: 249344...
# Epoch: 18/20... Step: 249600...
# Epoch: 18/20... Step: 249856...
# Epoch: 18/20... Step: 250112...
# Epoch: 18/20... Step: 250368...
# Epoch: 18/20... Step: 250624...
# Epoch: 18/20... Step: 250880...
# Epoch: 18/20... Step: 251136...
# Epoch: 18/20... Step: 251392...
# Epoch: 18/20... Step: 251648...
# Epoch: 18/20... Step: 251904...
# Epoch: 18/20... Step: 252160...
# Epoch: 18/20... Step: 252416...
# Epoch: 18/20... Step: 252672...
# Epoch: 18/20... Step: 252928...
# Epoch: 18/20... Step: 253184...
# Epoch: 18/20... Step: 253440...
# Epoch: 18/20... Step: 253696...
# Epoch: 18/20... Step: 253952...
# Epoch: 18/20... Step: 254208...
# Epoch: 18/20... Step: 254464...
# Epoch: 18/20... Step: 254720...
# Epoch: 18/20... Step: 254976...
# Epoch: 18/20... Step: 255232...
# Epoch: 18/20... Step: 255488...
# Epoch: 18/20... Step: 255744...
# Epoch: 18/20... Step: 256000...
# Epoch: 18/20... Step: 256256...
# Epoch: 18/20... Step: 256512...
# Epoch: 18/20... Step: 256768...
# Epoch: 18/20... Step: 257024...
# Epoch: 18/20... Step: 257280...
# Epoch: 18/20... Step: 257536...
# Epoch: 18/20... Step: 257792...
# Epoch: 18/20... Step: 258048...
# Epoch: 18/20... Step: 258304...
# Epoch: 18/20... Step: 258560...
# Epoch: 18/20... Step: 258816...
# Epoch: 18/20... Step: 259072...
# Epoch: 19/20... Step: 259328...
# Epoch: 19/20... Step: 259584...
# Epoch: 19/20... Step: 259840...
# Epoch: 19/20... Step: 260096...
# Epoch: 19/20... Step: 260352...
# Epoch: 19/20... Step: 260608...
# Epoch: 19/20... Step: 260864...
# Epoch: 19/20... Step: 261120...
# Epoch: 19/20... Step: 261376...
# Epoch: 19/20... Step: 261632...
# Epoch: 19/20... Step: 261888...
# Epoch: 19/20... Step: 262144...
# Epoch: 19/20... Step: 262400...
# Epoch: 19/20... Step: 262656...
# Epoch: 19/20... Step: 262912...
# Epoch: 19/20... Step: 263168...
# Epoch: 19/20... Step: 263424...
# Epoch: 19/20... Step: 263680...
# Epoch: 19/20... Step: 263936...
# Epoch: 19/20... Step: 264192...
# Epoch: 19/20... Step: 264448...
# Epoch: 19/20... Step: 264704...
# Epoch: 19/20... Step: 264960...
# Epoch: 19/20... Step: 265216...
# Epoch: 19/20... Step: 265472...
# Epoch: 19/20... Step: 265728...
# Epoch: 19/20... Step: 265984...
# Epoch: 19/20... Step: 266240...
# Epoch: 19/20... Step: 266496...
# Epoch: 19/20... Step: 266752...
# Epoch: 19/20... Step: 267008...
# Epoch: 19/20... Step: 267264...
# Epoch: 19/20... Step: 267520...
# Epoch: 19/20... Step: 267776...
# Epoch: 19/20... Step: 268032...
# Epoch: 19/20... Step: 268288...
# Epoch: 19/20... Step: 268544...
# Epoch: 19/20... Step: 268800...
# Epoch: 19/20... Step: 269056...
# Epoch: 19/20... Step: 269312...
# Epoch: 19/20... Step: 269568...
# Epoch: 19/20... Step: 269824...
# Epoch: 19/20... Step: 270080...
# Epoch: 19/20... Step: 270336...
# Epoch: 19/20... Step: 270592...
# Epoch: 19/20... Step: 270848...
# Epoch: 19/20... Step: 271104...
# Epoch: 19/20... Step: 271360...
# Epoch: 19/20... Step: 271616...
# Epoch: 19/20... Step: 271872...
# Epoch: 19/20... Step: 272128...
# Epoch: 19/20... Step: 272384...
# Epoch: 19/20... Step: 272640...
# Epoch: 19/20... Step: 272896...
# Epoch: 19/20... Step: 273152...
# Epoch: 19/20... Step: 273408...
# Epoch: 20/20... Step: 273664...
# Epoch: 20/20... Step: 273920...
# Epoch: 20/20... Step: 274176...
# Epoch: 20/20... Step: 274432...
# Epoch: 20/20... Step: 274688...
# Epoch: 20/20... Step: 274944...
# Epoch: 20/20... Step: 275200...
# Epoch: 20/20... Step: 275456...
# Epoch: 20/20... Step: 275712...
# Epoch: 20/20... Step: 275968...
# Epoch: 20/20... Step: 276224...
# Epoch: 20/20... Step: 276480...
# Epoch: 20/20... Step: 276736...
# Epoch: 20/20... Step: 276992...
# Epoch: 20/20... Step: 277248...
# Epoch: 20/20... Step: 277504...
# Epoch: 20/20... Step: 277760...
# Epoch: 20/20... Step: 278016...
# Epoch: 20/20... Step: 278272...
# Epoch: 20/20... Step: 278528...
# Epoch: 20/20... Step: 278784...
# Epoch: 20/20... Step: 279040...
# Epoch: 20/20... Step: 279296...
# Epoch: 20/20... Step: 279552...
# Epoch: 20/20... Step: 279808...
# Epoch: 20/20... Step: 280064...
# Epoch: 20/20... Step: 280320...
# Epoch: 20/20... Step: 280576...
# Epoch: 20/20... Step: 280832...
# Epoch: 20/20... Step: 281088...
# Epoch: 20/20... Step: 281344...
# Epoch: 20/20... Step: 281600...
# Epoch: 20/20... Step: 281856...
# Epoch: 20/20... Step: 282112...
# Epoch: 20/20... Step: 282368...
# Epoch: 20/20... Step: 282624...
# Epoch: 20/20... Step: 282880...
# Epoch: 20/20... Step: 283136...
# Epoch: 20/20... Step: 283392...
# Epoch: 20/20... Step: 283648...
# Epoch: 20/20... Step: 283904...
# Epoch: 20/20... Step: 284160...
# Epoch: 20/20... Step: 284416...
# Epoch: 20/20... Step: 284672...
# Epoch: 20/20... Step: 284928...
# Epoch: 20/20... Step: 285184...
# Epoch: 20/20... Step: 285440...
# Epoch: 20/20... Step: 285696...
# Epoch: 20/20... Step: 285952...
# Epoch: 20/20... Step: 286208...
# Epoch: 20/20... Step: 286464...
# Epoch: 20/20... Step: 286720...
# Epoch: 20/20... Step: 286976...
# Epoch: 20/20... Step: 287232...
# Epoch: 20/20... Step: 287488...
# Epoch: 20/20... Step: 287744...
# Epoch: 20/20... Step: 288000...

# %% [markdown]
# ### Prediction

# %%
net.load_state_dict(torch.load('/data-disk/rap/baseline.md'))
# Out:
# <All keys matched successfully>

# %%
import random

# predict next token
def predict(net, tkn, h=None):
         
  # tensor inputs
  x = np.array([[D.token2int[tkn]]])
  inputs = torch.from_numpy(x)
  
  # push to GPU
  inputs = inputs.cuda()

  # detach hidden state from history
  h = tuple([each.data for each in h])

  # get the output of the model
  out, h = net(inputs, h)

  # get the token probabilities
  p = F.softmax(out, dim=1).data

  p = p.cpu()

  p = p.numpy()
  p = p.reshape(p.shape[1],)

  # get indices of top 3 values
  top_n_idx = p.argsort()[-3:][::-1]

  # randomly select one of the three indices
  sampled_token_index = top_n_idx[random.sample([0,1,2],1)[0]]

  # return the encoded value of the predicted char and the hidden state
  return D.int2token[sampled_token_index], h


# function to generate text
def sample(net, size, prime='it is'):
        
    # push to GPU
    net.cuda()
    
    net.eval()

    # batch size is 1
    h = net.init_hidden(1)

    toks = prime.split()

    # predict next token
    for t in prime.split():
      token, h = predict(net, t, h)
    
    toks.append(token)

    # predict subsequent tokens
    for i in range(size-1):
        token, h = predict(net, toks[-1], h)
        toks.append(token)

    return ' '.join(toks)

# %%
sample(net, 100, prime = "this rap is lit")
# Out:
# "this rap is lit it out the club bottle full of bub t all on my dick 'm the one in a pot prinkle the money on me 'm so whoa whoa whoa 'll be your best friends close for me ou know that we handsome e ballin away for a track of a kind of bub ook mami come up with me 'm a smooth nigga you ain't a game and the hood you can be my bitch and the sun and my name is noccut eft up in a pot a lil mama put me in a pot prinkle a little something"

# %%
torch.save(net, '/data-disk/rap/baseline.md')
# Out:
# /root/miniconda3/lib/python3.7/site-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type WordLSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
